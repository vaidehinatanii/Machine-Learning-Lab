# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", np.nan, "D"],
    "Age": [20, np.nan, 22, 23, 21],
    "Marks": [85, 90, np.nan, 88, 92],
    "City": ["Delhi", "Mumbai", "Chennai", "Kolkata", np.nan]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

print("\nMissing values (True indicates missing):")
print(df.isnull())

print("\nNon-missing values (True indicates not missing):")
print(df.notnull())

print("\nTotal missing values in each column:")
print(df.isnull().sum())

import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", np.nan, "D"],
    "Age": [20, np.nan, 22, 23, 21],
    "Marks": [85, 90, np.nan, 88, 92],
    "City": ["Delhi", "Mumbai", "Chennai", "Kolkata", np.nan]
}

df = pd.DataFrame(data)

print("Original Dataset:")
print(df)

print("\nDataset size before cleaning:")
print(df.shape)

clean_df = df.dropna()

print("\nCleaned Dataset (Rows with missing values removed):")
print(clean_df)

print("\nDataset size after cleaning:")
print(clean_df.shape)

import pandas as pd
import numpy as np

data = {
    "Name": ["A", "B", "C", np.nan, "D", "E"],
    "Age": [20, np.nan, 22, 23, 21, 24],
    "Marks": [85, 90, np.nan, 88, 92, 95],
    "City": ["Delhi", "Mumbai", "Chennai", "Kolkata", np.nan, "Bangalore"]
}

df = pd.DataFrame(data)

print("Original Dataset:")
print(df)

df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].median())
df["Name"] = df["Name"].fillna("Unknown")
df["City"] = df["City"].fillna("Not Available")

print("\nDataset after handling missing values:")
print(df)

import pandas as pd

data = {
    "Name": ["A", "B", "C", "D", "E"],
    "Age": [20, 21, 22, 23, 24],
    "Marks": [85, 90, 88, 92, 95],
    "Passed": [True, False, True, True, False]
}

df = pd.DataFrame(data)

print("Original Data Types:")
print(df.dtypes)

df["Age"] = df["Age"].astype("int32")
df["Marks"] = df["Marks"].astype("float64")

print("\nData Types After Conversion:")
print(df.dtypes)

import pandas as pd

data = {
    "Name": ["A", "B", "C", "D", "E"],
    "Age": [20, 21, 22, 23, 24],
    "Marks": [85, 90, 88, 92, 95],
    "Passed": [True, False, True, True, False]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

df = df.rename(columns={
    "Name": "Student_Name",
    "Age": "Student_Age",
    "Marks": "Student_Marks",
    "Passed": "Result"
})

print("\nUpdated DataFrame after renaming columns:")
print(df)

import pandas as pd

data = {
    "Gender": ["Male", "M", "Female", "F", "male", "female"]
}

df = pd.DataFrame(data)

print("Original Data:")
print(df)

df["Gender"] = df["Gender"].replace({
    "M": "Male",
    "F": "Female",
    "male": "Male",
    "female": "Female"
})

print("\nCorrected Data:")
print(df)

import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Month": ["Jan","Feb","Mar","Jan","Feb","Mar","Jan","Feb","Mar"],
    "Sales": [100,150,130,120,160,140,110,155,135],
    "Region": ["North","North","North","South","South","South","East","East","East"]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

monthly_sales = df.groupby("Month")["Sales"].sum()

plt.plot(monthly_sales.index, monthly_sales.values, marker="o")
plt.title("Sales Trend Over Time")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(kind="bar")
plt.title("Total Sales by Region")
plt.ylabel("Total Sales")
plt.show()

import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Student": list("ABCDEFGHIJ"),
    "Hours_Studied": [2,4,3,5,6,1,7,8,3,5],
    "Marks_Obtained": [50,65,55,70,80,40,85,90,60,75]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

plt.scatter(df["Hours_Studied"], df["Marks_Obtained"])
plt.title("Scatter Plot: Hours Studied vs Marks Obtained")
plt.xlabel("Hours Studied")
plt.ylabel("Marks Obtained")
plt.show()

correlation = df["Hours_Studied"].corr(df["Marks_Obtained"])
print("\nCorrelation between Hours Studied and Marks Obtained:", round(correlation,2))

import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Student": list("ABCDEFGHIJ"),
    "Marks": [50,65,55,70,80,40,85,90,60,75]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

plt.hist(df["Marks"], bins=5)
plt.title("Histogram of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

print("\nMean:", df["Marks"].mean())
print("Median:", df["Marks"].median())
print("Skewness:", round(df["Marks"].skew(),2))

import pandas as pd
import matplotlib.pyplot as plt

data = {
    "Student": list("ABCDEFGHIJ"),
    "Marks": [50,65,55,70,80,40,85,90,60,200]
}

df = pd.DataFrame(data)

print("Dataset:")
print(df)

plt.boxplot(df["Marks"])
plt.title("Box Plot of Marks")
plt.ylabel("Marks")
plt.show()

Q1 = df["Marks"].quantile(0.25)
Q3 = df["Marks"].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df["Marks"] < Q1 - 1.5*IQR) | (df["Marks"] > Q3 + 1.5*IQR)]

print("\nPotential Outliers:")
print(outliers)
# Out:
# Dataset:
#   Name   Age  Marks     City
# 0    A  20.0   85.0    Delhi
# 1    B   NaN   90.0   Mumbai
# 2    C  22.0    NaN  Chennai
# 3  NaN  23.0   88.0  Kolkata
# 4    D  21.0   92.0      NaN
#
# Missing values (True indicates missing):
#     Name    Age  Marks   City
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True  False
# 3   True  False  False  False
# 4  False  False  False   True
#
# Non-missing values (True indicates not missing):
#     Name    Age  Marks   City
# 0   True   True   True   True
# 1   True  False   True   True
# 2   True   True  False   True
# 3  False   True   True   True
# 4   True   True   True  False
#
# Total missing values in each column:
# Name     1
# Age      1
# Marks    1
# City     1
# dtype: int64
# Original Dataset:
#   Name   Age  Marks     City
# 0    A  20.0   85.0    Delhi
# 1    B   NaN   90.0   Mumbai
# 2    C  22.0    NaN  Chennai
# 3  NaN  23.0   88.0  Kolkata
# 4    D  21.0   92.0      NaN
#
# ...
